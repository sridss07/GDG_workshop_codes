# %% [markdown]
# <a href="https://colab.research.google.com/github/sridss07/GDG_workshop_codes/blob/main/GDG_DAY_1_GEN_AI(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim

# %%
import nltk
from gensim.models import Word2Vec
nltk.download('punkt')

text = "Chandragupta Maurya (350–295 BCE) was Emperor of Magadha from 322 BC to 297 BC and founder of the Maurya dynasty which ruled over a geographically-extensive empire based in Magadha. He reigned from 320 BCE to 298 BCE"

sentences = nltk.sent_tokenize(text)  # Split text into sentences
tokenized_sentences = [nltk.word_tokenize(sentence.lower()) for sentence in sentences]  # Tokenize each sentence into words

model = Word2Vec(tokenized_sentences, vector_size=100, window=5, min_count=1, workers=4)

unique_words = set(word for sentence in tokenized_sentences for word in sentence)

for word in unique_words:
    similar_words = model.wv.most_similar(word, topn=5)
    print(f"Most similar words to '{word}':")
    for similar_word, similarity in similar_words:
        print(f"- {similar_word} (similarity: {similarity:.4f})")
    print()

model.save('word2vec.model')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Most similar words to '320':
# - in (similarity: 0.2853)
# - of (similarity: 0.1991)
# - dynasty (similarity: 0.0967)
# - magadha (similarity: 0.0752)
# - bc (similarity: 0.0606)
#
# Most similar words to 'of':
# - 320 (similarity: 0.1991)
# - ) (similarity: 0.1729)
# - he (similarity: 0.1713)
# - from (similarity: 0.1702)
# - the (similarity: 0.1527)
#
# Most similar words to '(':
# - bce (similarity: 0.2161)
# - . (similarity: 0.1265)
# - he (similarity: 0.1030)
# - based (similarity: 0.0839)
# - over (similarity: 0.0778)
#
# Most similar words to 'bce':
# - and (similarity: 0.2189)
# - ( (similarity: 0.2161)
# - . (similarity: 0.1955)
# - reigned (similarity: 0.1520)
# - in (similarity: 0.0995)
#
# Most similar words to 'dynasty':
# - 298 (similarity: 0.3189)
# - . (similarity: 0.1888)
# - 322 (similarity: 0.1621)
# - empire (similarity: 0.1277)
# ...
